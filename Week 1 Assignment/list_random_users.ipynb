# %%
import requests

# %%
res = requests.get("https://randomuser.me/api", params={"results":100,"gender":"male"})

# %%
res.json()
# Out:
# {'results': [{'gender': 'male',
#    'name': {'title': 'Mr', 'first': 'Zachary', 'last': 'Novak'},
#    'location': {'street': {'number': 749, 'name': '15th St'},
#     'city': 'Cartwright',
#     'state': 'New Brunswick',
#     'country': 'Canada',
#     'postcode': 'N8E 6U5',
#     'coordinates': {'latitude': '-65.7060', 'longitude': '170.1077'},
#     'timezone': {'offset': '+5:00',
#      'description': 'Ekaterinburg, Islamabad, Karachi, Tashkent'}},
#    'email': 'zachary.novak@example.com',
#    'login': {'uuid': 'ba10242a-2594-4970-8bc1-1e061c560b97',
#     'username': 'redrabbit171',
#     'password': 'lala',
#     'salt': 'OltMsJEd',
#     'md5': '32ef78e8cf6721b3c7a19418f82b2c86',
#     'sha1': '61e6f9d58a1a9680ccd142663559cb7dae6360f1',
#     'sha256': '9b075c0bb015f2bc2a671e066dbd1cfac5534d582c4c6733dd97147a2d5908cd'},
#    'dob': {'date': '1949-06-10T00:06:22.403Z', 'age': 73},
#    'registered': {'date': '2020-03-03T18:35:48.197Z', 'age': 2},
# ...
