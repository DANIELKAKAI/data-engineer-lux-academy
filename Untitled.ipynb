# %%
conda install pandas
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/danielkakai/miniforge3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1t             |       h03a7124_0         1.5 MB  conda-forge
#     pandas-1.5.3               |   py39hde7b980_0        10.6 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             conda-forge/osx-arm64::pandas-1.5.3-py39hde7b980_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1s-h03a7124_1 --> 1.1.1t-h03a7124_0
#
#
#
# ...
# pandas-1.5.3         | 10.6 MB   |                                       |   0%
# ...

# %%
conda install requests
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/danielkakai/miniforge3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     requests-2.28.2            |     pyhd8ed1ab_0          55 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          55 KB
#
# The following packages will be UPDATED:
#
#   requests                              2.28.1-pyhd8ed1ab_0 --> 2.28.2-pyhd8ed1ab_0
#
#
#
# ...
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install seaborn
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/danielkakai/miniforge3
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.0.7            |   py39haaf3ac1_0         196 KB  conda-forge
#     fonttools-4.38.0           |   py39h02fc5c5_1         1.9 MB  conda-forge
#     kiwisolver-1.4.4           |   py39haaf3ac1_1          62 KB  conda-forge
#     matplotlib-base-3.6.3      |   py39h35e9e80_0         6.2 MB  conda-forge
#     patsy-0.5.3                |     pyhd8ed1ab_0         189 KB  conda-forge
#     seaborn-0.12.2             |       hd8ed1ab_0           6 KB  conda-forge
#     seaborn-base-0.12.2        |     pyhd8ed1ab_0         226 KB  conda-forge
#     statsmodels-0.13.5         |   py39h4d8bf0d_2        10.6 MB  conda-forge
# ...
